# %%
import pandas as pd
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\C\Spam detection.ipynb Cell 1 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/C/Spam%20detection.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib as mpl
#       <a href='vscode-notebook-cell:/d%3A/C/Spam%20detection.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/d%3A/C/Spam%20detection.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/d%3A/C/Spam%20detection.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> import mpl_toolkits
#       <a href='vscode-notebook-cell:/d%3A/C/Spam%20detection.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# Python program to read CSV file line by line
# import necessary packages
import csv
import sys
def read_csv(file_name):
  with open(file_name) as file_obj:
    
    # Create reader object by passing the file
    # object to reader method
    reader_obj = csv.reader(file_obj)
    
    # Iterate over each row in the csv
    # file using reader object
    arr = []
    for row in reader_obj:
      if len(row) == 865 :
        arr.append(row)

    return arr

# %%
data_train = read_csv('/data_3_days.csv')

# %%
data_train = np.array(data_train).astype(np.float32)

# %%
data_train.shape
# Out:
# (34660, 865)

# %%
# df_data_train = pd.DataFrame(data_train)

# %%
# df_data_train.head(20)
# Out:
#             0            1            2            3            4    \
# 0    1235554595   1073505553    937629111    837074314    839917312
# 1    2449710232   2509151719   2497613271   2387182513   2642587883
# 2   15707561185  16026034951  16088569599  16200421582  15776426926
# 3    1277143970   1220418879   1284054521   1254376922   1273429640
# 4    3123555840   3558347490   4058829281   3137983967   3196649179
# 5    3976259391   4040762097   3979965459   3754230337   3699554487
# 6    4032633299   3790499709   3800337230   3963467365   3596663651
# 7    7571641235   6859244788   6438907472   6073497055   6411232175
# 8    1180808569    926316623   1172108855   1147444967   1125043060
# 9    4547880499   3840732785   3377528038   3294925802   2768295269
# 10      7764115     10521507      9064484      7461971      4654933
# 11   2395824425   2206790605   2782522074   2731715667   2672434477
# 12   2227978755   2197718571   2289808423   2023610293   1986086508
# ...

# %%
# df_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34660 entries, 0 to 34659
# Columns: 865 entries, 0 to 864
# dtypes: object(865)
# memory usage: 228.7+ MB

# %%
X_train = data_train[:, 0:864]
y_train = data_train[:,-1]

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# y_train = pd.to_numeric(y_train)

# %%
y_train
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
print(sum(y_train==1), sum(y_train==0))
# Out:
# 5219 29441

# %%
X_train
# Out:
# array([[1.23555456e+09, 1.07350554e+09, 9.37629120e+08, ...,
#         4.70959648e+08, 5.44833856e+08, 3.13259808e+08],
#        [2.44971034e+09, 2.50915174e+09, 2.49761331e+09, ...,
#         2.38116787e+09, 2.47711974e+09, 1.80411430e+09],
#        [1.57075610e+10, 1.60260352e+10, 1.60885699e+10, ...,
#         1.18270950e+09, 1.16840870e+09, 7.33166272e+08],
#        ...,
#        [4.06897997e+09, 3.17299891e+09, 2.81487744e+09, ...,
#         4.69233920e+09, 2.00719168e+09, 1.00565677e+09],
#        [7.42662080e+07, 1.47635344e+08, 5.73265080e+07, ...,
#         5.35538800e+07, 1.02869312e+08, 5.59748600e+07],
#        [7.14667648e+08, 4.03871744e+08, 1.16870008e+08, ...,
#         2.28801008e+08, 3.61914560e+08, 2.29436544e+08]], dtype=float32)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (34660, 864) (34660,)

# %%
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# y_train = le.fit_transform(y_train)

# %%
model = XGBClassifier(n_estimators=500, learning_rate=0.1, eta=0.1, max_depth=5)
model.fit(X_train, y_train)
